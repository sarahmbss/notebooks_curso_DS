# %%
#### Mineração de texto

# %%
# Importação das bibliotecas
import matplotlib.pyplot as plt
import nltk
nltk.download('stopwords')
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
from matplotlib.colors import ListedColormap
from wordcloud import WordCloud
import string
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Sarah
# [nltk_data]     Braga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Criação de um corpus lendo textos do disco
corpus = PlaintextCorpusReader('C:\\Users\\Sarah Braga\\Desktop\\mineracao_curso', '.*', encoding = "ISO-8859-1") #caminho, filtro de leitura e codificação

# %%
# Leitura dos arquivos do disco, percorrer os registros e mostrar o nome dos primeiros 100 arquivos
arquivos = corpus.fileids()
#primeiro arquivo
arquivos[0]
# Out:
# '1.txt'

# %%
#zero a 10
arquivos[0:10]
# Out:
# ['1.txt',
#  '10.txt',
#  '100.txt',
#  '1000.txt',
#  '1001.txt',
#  '1002.txt',
#  '1003.txt',
#  '1004.txt',
#  '1005.txt',
#  '1006.txt']

# %%
# Acesso ao texto do primeiro arquivo
texto = corpus.raw('1.txt') #sem parametro ele pega as palavras de todos os arquivos da pasta
texto
# Out:
# "@relation 'Reuters-21578 Corn ModApte Train-weka.filters.unsupervised.attribute.NumericToBinary-weka.filters.unsupervised.instance.RemoveFolds-S0-N5-F1'\r\n"

# %%
todo_texto=corpus.raw() #acesso a todas as palavras do texto

# %%
# Obtenção de todas as palavras do corpus e visualização da quantidade
palavras = corpus.words()
#acessando pelo indíce
palavras[170]
# Out:
# 'dividend'

# %%
#quantidade
len(palavras)
# Out:
# 244913

# %%
# Usando o NLTK, obtemos as stop word em inglês
stops = stopwords.words('english') #o arquivo está em inglês

# %%
# Definição das cores que serão utilizadas na nuvem de palavras
mapa_cores = ListedColormap(['blue', 'black', 'yellow', 'pink'])
# Criação da nuvem de palavras, com no máximo 100 palavras e utilizando as stop words
nuvem = WordCloud(background_color = 'white',
                  colormap = mapa_cores,
                  stopwords = stops,
                  max_words = 100)
# Criação e visualização da nuvem de palavras
nuvem.generate(todo_texto)
plt.imshow(nuvem)

# %%
# Criação de nova lista de palavras, removendo stop words
palavras_semstop = [p for p in palavras if p not in stops]
len(palavras_semstop)
# Out:
# 189446

# %%
# Remoção da pontuação, gerando uma lista sem stop words e sem pontuação
palavras_sem_pontuacao = [p for p in palavras_semstop if p not in string.punctuation]
len(palavras_sem_pontuacao)
# Out:
# 156687

# %%
# Cálculo da frequência das palavras e visualização das mais comuns
frequencia = nltk.FreqDist(palavras_sem_pontuacao)

# %%
#mais comuns
mais_comuns = frequencia.most_common(100)
mais_comuns
# Out:
# [('said', 3398),
#  ('mln', 2721),
#  ('3', 2228),
#  ('vs', 2194),
#  ('0', 1949),
#  ('dlrs', 1945),
#  ('1', 1661),
#  ('000', 1640),
#  ('&#', 1466),
#  (";',", 1432),
#  ('The', 1429),
#  ('cts', 1374),
#  ('lt', 1286),
#  ('Reuter', 1214),
#  ('pct', 1146),
#  ('2', 1001),
#  ('year', 878),
#  ('U', 833),
#  ('loss', 800),
#  ('S', 794),
#  ('billion', 707),
#  ('5', 674),
#  ('1986', 666),
#  ('would', 638),
#  ('4', 633),
#  ('company', 518),
#  ('share', 513),
#  ('6', 505),
#  ('profit', 498),
#  ('Net', 486),
#  ('7', 469),
#  ('Shr', 456),
#  ('8', 440),
#  ('March', 439),
#  ('net', 401),
#  ('9', 393),
#  ('Revs', 392),
#  ('one', 390),
#  ('Inc', 385),
#  ('last', 380),
#  ('tonnes', 361),
#  ('market', 357),
#  ('also', 355),
#  ('shares', 351),
#  ('per', 347),
#  ('two', 340),
#  ('stock', 339),
#  ('oil', 328),
#  ('prices', 325),
#  ('10', 315),
#  ('1985', 309),
#  ('QTR', 300),
#  ('1987', 298),
#  ('31', 295),
#  ('It', 294),
#  ('trade', 290),
#  ('quarter', 284),
#  ('Corp', 277),
#  ('12', 272),
#  ('January', 272),
#  ('15', 271),
#  ('April', 244),
#  ('Oper', 244),
#  ('TO', 240),
#  ('Bank', 240),
#  ('February', 236),
#  ('NET', 229),
#  ('price', 229),
#  ('REUTER', 227),
#  ('16', 223),
#  ('13', 222),
#  ('He', 217),
#  ('new', 216),
#  ('25', 216),
#  ('week', 215),
#  ('A', 214),
#  ('INC', 213),
#  ('offer', 210),
#  ('20', 208),
#  ('December', 206),
#  ('50', 205),
#  ('rate', 205),
#  ('rose', 200),
#  ('three', 198),
#  ('today', 196),
#  ('4TH', 195),
#  ('In', 191),
#  ('sales', 191),
#  ('Co', 189),
#  ('five', 187),
#  ('30', 187),
#  ('group', 187),
#  ('--', 183),
#  ('expected', 179),
#  ('government', 178),
#  ('shr', 174),
#  ('total', 173),
#  ('IN', 173),
#  ('common', 172),
#  ('dlr', 171)]
